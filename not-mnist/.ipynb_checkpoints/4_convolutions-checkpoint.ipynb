# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %% [raw]
# batch_size = 16
# patch_size = 5
# depth = 16
# num_hidden = 64
#
# graph = tf.Graph()
#
# with graph.as_default():
#
#   # Input data.
#   tf_train_dataset = tf.placeholder(
#     tf.float32, shape=(batch_size, image_size, image_size, num_channels))
#   tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
#   tf_valid_dataset = tf.constant(valid_dataset)
#   tf_test_dataset = tf.constant(test_dataset)
#
#   # Variables.
#   layer1_weights = tf.Variable(tf.truncated_normal(
#       [patch_size, patch_size, num_channels, depth], stddev=0.1))
#   layer1_biases = tf.Variable(tf.zeros([depth]))
#   layer2_weights = tf.Variable(tf.truncated_normal(
#       [patch_size, patch_size, depth, depth], stddev=0.1))
#   layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
#   layer3_weights = tf.Variable(tf.truncated_normal(
#       [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
#   layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
#   layer4_weights = tf.Variable(tf.truncated_normal(
#       [num_hidden, num_labels], stddev=0.1))
#   layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
#
#   # Model.
#   def model(data):
#     conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
#     hidden = tf.nn.relu(conv + layer1_biases)
#     conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
#     hidden = tf.nn.relu(conv + layer2_biases)
#     shape = hidden.get_shape().as_list()
#     reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
#     hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
#     return tf.matmul(hidden, layer4_weights) + layer4_biases
#
#   # Training computation.
#   logits = model(tf_train_dataset)
#   loss = tf.reduce_mean(
#     tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
#
#   # Optimizer.
#   optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
#
#   # Predictions for the training, validation, and test data.
#   train_prediction = tf.nn.softmax(logits)
#   valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
#   test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %% [raw]
# num_steps = 1001
#
# with tf.Session(graph=graph) as session:
#   tf.global_variables_initializer().run()
#   print('Initialized')
#   for step in range(num_steps):
#     offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
#     batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
#     batch_labels = train_labels[offset:(offset + batch_size), :]
#     feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
#     _, l, predictions = session.run(
#       [optimizer, loss, train_prediction], feed_dict=feed_dict)
#     if (step % 500 == 0):
#       print('Minibatch loss at step %d: %f' % (step, l))
#       print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
#       print('Validation accuracy: %.1f%%' % accuracy(
#         valid_prediction.eval(), valid_labels))
#   print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %% [raw]
# image_size = 28
# num_labels = 10
# num_channels = 1 # grayscale
#
# batch_size = 16
# patch_size = 5
# depth = 16
# num_hidden = 64
#
# graph = tf.Graph()
#
# with graph.as_default():
#
#   # Input data.
#   tf_train_dataset = tf.placeholder(
#     tf.float32, shape=(batch_size, image_size, image_size, num_channels))
#   tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
#   tf_valid_dataset = tf.constant(valid_dataset)
#   tf_test_dataset = tf.constant(test_dataset)
#
#   # Variables.
#   layer1_weights = tf.Variable(tf.truncated_normal(
#       [patch_size, patch_size, num_channels, depth], stddev=0.1))
#   layer1_biases = tf.Variable(tf.zeros([depth]))
#
#   layer2_weights = tf.Variable(tf.truncated_normal(
#       [patch_size, patch_size, depth, depth], stddev=0.1))
#   layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
#
#   layer3_weights = tf.Variable(tf.truncated_normal(
#       [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
#   layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
#
#   layer4_weights = tf.Variable(tf.truncated_normal(
#       [num_hidden, num_labels], stddev=0.1))
#   layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
#
#   # Model.
#   def model(data):
#     conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
#     pool = tf.layers.max_pooling2d(conv, 2, 2)
#     hidden = tf.nn.relu(pool + layer1_biases)
#     conv = tf.nn.conv2d(hidden, layer2_weights, [1, 1, 1, 1], padding='SAME')
#     pool = tf.layers.max_pooling2d(conv, 2, 2)
#     hidden = tf.nn.relu(pool + layer2_biases)
#     shape = hidden.get_shape().as_list()
#     reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
#     hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
#     return tf.matmul(hidden, layer4_weights) + layer4_biases
#
#   # Training computation.
#   logits = model(tf_train_dataset)
#   loss = tf.reduce_mean(
#     tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
#
#   # Optimizer.
#   optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
#
#   # Predictions for the training, validation, and test data.
#   train_prediction = tf.nn.softmax(logits)
#   valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
#   test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %% [markdown]
# num_steps = 1001
#
# with tf.Session(graph=graph) as session:
#   tf.global_variables_initializer().run()
#   print('Initialized')
#   for step in range(num_steps):
#     offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
#     batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
#     batch_labels = train_labels[offset:(offset + batch_size), :]
#     feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
#     _, l, predictions = session.run(
#       [optimizer, loss, train_prediction], feed_dict=feed_dict)
#     if (step % 500 == 0):
#       print('Minibatch loss at step %d: %f' % (step, l))
#       print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
#       print('Validation accuracy: %.1f%%' % accuracy(
#         valid_prediction.eval(), valid_labels))
#   print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

batch_size = 16
patch_size = 14
depth = 16
num_hidden = 64
num_hidden2 = 32
beta = 0.001

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  
  layer3_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[depth]))

  layer4_weights = tf.Variable(tf.truncated_normal(
      [image_size // 8 * image_size // 8 * depth - depth, num_hidden2], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden2]))

  layer5_weights = tf.Variable(tf.truncated_normal(
      [num_hidden2, num_hidden], stddev=0.1))
  layer5_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))

  layer6_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer6_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    pool = tf.layers.max_pooling2d(conv, 2, 2)
    hidden = tf.nn.relu(pool + layer1_biases)
    
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 1, 1, 1], padding='SAME')
    pool = tf.layers.max_pooling2d(conv, 2, 2)
    hidden = tf.nn.relu(pool + layer2_biases)
    
    conv = tf.nn.conv2d(hidden, layer3_weights, [1, 1, 1, 1], padding='SAME')
    pool = tf.layers.average_pooling2d(conv, 2, 2)
    hidden = tf.nn.relu(pool + layer3_biases)
    
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer4_weights) + layer4_biases)
    hidden = tf.nn.relu(tf.matmul(hidden, layer5_weights) + layer5_biases)
    
    return tf.matmul(hidden, layer6_weights) + layer6_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
  regularizers = tf.nn.l2_loss(layer1_weights) + tf.nn.l2_loss(layer2_weights) + tf.nn.l2_loss(layer3_weights) + tf.nn.l2_loss(layer4_weights) + tf.nn.l2_loss(layer5_weights) + tf.nn.l2_loss(layer6_weights)
  loss = tf.reduce_mean(loss + beta*regularizers)
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 10001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 100 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.314758
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 100: 2.139349
# Minibatch accuracy: 43.8%
# Validation accuracy: 51.5%
# Minibatch loss at step 200: 1.140551
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.0%
# Minibatch loss at step 300: 1.942956
# Minibatch accuracy: 62.5%
# Validation accuracy: 78.2%
# Minibatch loss at step 400: 1.198332
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.8%
# Minibatch loss at step 500: 1.316709
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.1%
# Minibatch loss at step 600: 0.825652
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.8%
# Minibatch loss at step 700: 1.394796
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.4%
# Minibatch loss at step 800: 0.805304
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.1%
# Minibatch loss at step 900: 1.054280
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.0%
# Minibatch loss at step 1000: 1.126089
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.4%
# Minibatch loss at step 1100: 0.760274
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.5%
# Minibatch loss at step 1200: 1.409180
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.7%
# Minibatch loss at step 1300: 0.891563
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.2%
# Minibatch loss at step 1400: 0.551972
# Minibatch accuracy: 100.0%
# Validation accuracy: 84.9%
# Minibatch loss at step 1500: 0.780949
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.2%
# Minibatch loss at step 1600: 0.653962
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.5%
# Minibatch loss at step 1700: 0.409883
# Minibatch accuracy: 100.0%
# Validation accuracy: 84.5%
# Minibatch loss at step 1800: 1.547160
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.9%
# Minibatch loss at step 1900: 0.448950
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.5%
# Minibatch loss at step 2000: 0.945135
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.3%
# Minibatch loss at step 2100: 1.064148
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.2%
# Minibatch loss at step 2200: 0.577709
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.1%
# Minibatch loss at step 2300: 0.970367
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.7%
# Minibatch loss at step 2400: 0.648017
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.2%
# Minibatch loss at step 2500: 0.730972
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.3%
# Minibatch loss at step 2600: 1.174077
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.8%
# Minibatch loss at step 2700: 0.732523
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.2%
# Minibatch loss at step 2800: 0.904051
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.2%
# Minibatch loss at step 2900: 0.610262
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.6%
# Minibatch loss at step 3000: 0.899841
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.5%
# Minibatch loss at step 3100: 0.572283
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.1%
# Minibatch loss at step 3200: 0.679323
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.7%
# Minibatch loss at step 3300: 1.025586
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.1%
# Minibatch loss at step 3400: 0.933231
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.0%
# Minibatch loss at step 3500: 0.647565
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.1%
# Minibatch loss at step 3600: 1.076142
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.0%
# Minibatch loss at step 3700: 0.387817
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.5%
# Minibatch loss at step 3800: 0.757684
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.7%
# Minibatch loss at step 3900: 0.617739
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.3%
# Minibatch loss at step 4000: 1.359639
# Minibatch accuracy: 68.8%
# Validation accuracy: 86.5%
# Minibatch loss at step 4100: 0.419341
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.1%
# Minibatch loss at step 4200: 0.625349
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.7%
# Minibatch loss at step 4300: 0.379230
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.2%
# Minibatch loss at step 4400: 0.859333
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.2%
# Minibatch loss at step 4500: 0.583932
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.0%
# Minibatch loss at step 4600: 0.659050
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.5%
# Minibatch loss at step 4700: 0.655136
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.4%
# Minibatch loss at step 4800: 0.845097
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.0%
# Minibatch loss at step 4900: 0.337932
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.0%
# Minibatch loss at step 5000: 0.867840
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.5%
# Minibatch loss at step 5100: 0.640318
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.4%
# Minibatch loss at step 5200: 0.862810
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.0%
# Minibatch loss at step 5300: 0.502344
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.1%
# Minibatch loss at step 5400: 0.618041
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.8%
# Minibatch loss at step 5500: 0.512948
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.8%
# Minibatch loss at step 5600: 0.914526
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.9%
# Minibatch loss at step 5700: 0.479478
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.9%
# Minibatch loss at step 5800: 0.752216
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.1%
# Minibatch loss at step 5900: 0.737477
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.5%
# Minibatch loss at step 6000: 0.909400
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.8%
# Minibatch loss at step 6100: 0.661886
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.2%
# Minibatch loss at step 6200: 0.434692
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.7%
# Minibatch loss at step 6300: 0.863111
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.9%
# Minibatch loss at step 6400: 0.986482
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.0%
# Minibatch loss at step 6500: 0.668245
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.4%
# Minibatch loss at step 6600: 0.472994
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.0%
# Minibatch loss at step 6700: 0.580768
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.8%
# Minibatch loss at step 6800: 0.505639
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.0%
# Minibatch loss at step 6900: 0.635349
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.2%
# Minibatch loss at step 7000: 0.588238
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.2%
# Minibatch loss at step 7100: 0.534567
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.0%
# Minibatch loss at step 7200: 0.407327
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.1%
# Minibatch loss at step 7300: 0.613310
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.1%
# Minibatch loss at step 7400: 0.697299
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.7%
# Minibatch loss at step 7500: 1.329659
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.1%
# Minibatch loss at step 7600: 0.910152
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.1%
# Minibatch loss at step 7700: 0.562211
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.1%
# Minibatch loss at step 7800: 0.748409
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.8%
# Minibatch loss at step 7900: 0.316500
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.1%
# Minibatch loss at step 8000: 0.706350
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.4%
# Minibatch loss at step 8100: 0.703582
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.8%
# Minibatch loss at step 8200: 0.755358
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.9%
# Minibatch loss at step 8300: 0.755357
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.6%
# Minibatch loss at step 8400: 1.353405
# Minibatch accuracy: 68.8%
# Validation accuracy: 88.1%
# Minibatch loss at step 8500: 0.943985
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.0%
# Minibatch loss at step 8600: 0.295438
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.5%
# Minibatch loss at step 8700: 0.901913
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.2%
# Minibatch loss at step 8800: 0.457900
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.3%
# Minibatch loss at step 8900: 1.123033
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.6%
# Minibatch loss at step 9000: 0.904790
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.7%
# Minibatch loss at step 9100: 0.460076
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.4%
# Minibatch loss at step 9200: 0.561891
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.6%
# Minibatch loss at step 9300: 0.437069
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.2%
# Minibatch loss at step 9400: 0.772466
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.0%
# Minibatch loss at step 9500: 0.480888
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.7%
# Minibatch loss at step 9600: 0.254912
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.1%
# Minibatch loss at step 9700: 0.467808
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# Minibatch loss at step 9800: 0.472156
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.5%
# Minibatch loss at step 9900: 0.439442
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.7%
# Minibatch loss at step 10000: 0.566820
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.6%
# Test accuracy: 94.2%
